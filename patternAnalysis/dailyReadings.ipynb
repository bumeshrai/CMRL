# %% [markdown]
# Python programme to process the energy readings.
#
# Readings here are at a day interval
#
# Author: Dr. B. Umesh Rai

# %%
import matplotlib.pyplot as plt
import numpy as np 
import os

# Backup in another file
with open("csv/consumption.csv") as fileToRead:
    with open("csv/backupDaily.csv", "w") as fileToWrite:
        for line in fileToRead:
            fileToWrite.write(line)
fileToRead.close()
fileToWrite.close()

# %%
# change the slash to dot for naming the files
def slash2dot(str):
    dateSplit = str.split('/')
    return(".".join(dateSplit))

# Line counter
i = 0
# Define a variable to check the date of data
startDate = ''
# Ignore the first row as it is an header
counterStart = 1
# List array variable to capture field
list = []
# List of csv files that will be created
files = []

with open("csv/consumption.csv") as fileToRead:
    for line in fileToRead:
        i +=1
        
        # Capture the field data in the csv file 
        # split by comma
        list = line.split(',')
        
        # Create a new file as the data for preceeding date is over
        if (list[0] != startDate) & (i > counterStart):
            # First field is the date variable
            startDate = list[0]
            # New csv file with the date created
            newFile = slash2dot(startDate + '.csv')
            newFile = 'temp/' + newFile 
            # Save the file name
            files.append(newFile)

        # Write the data to the file
        if i > counterStart:
            fileToWrite = open(newFile, "a")
            fileToWrite.write(line)
            fileToWrite.close()
    
    fileToRead.close()
    
#print(files)

# %%
# Change from time format seperator ':' to '.'
# The last time is 00:00, this has to be 
# changed to 24.00
def colons2dot(str):
    timeSplit = str.split(':')
    if ".".join(timeSplit) != '00.00':
        return(".".join(timeSplit))
    else:
        return("24.00")

# %%
timeOfReading_26 = []
import110_26 = []
export110_26 = []
import33_26 = []
export33_26 = []
import25_26 = []
export25_26 = []

with open("temp/26.11.19.csv") as fileToRead:
    for line in fileToRead:
        list = line.split(',')
        timeOfReading_26.append(float(colons2dot(list[1])))
        import110_26.append(float(list[2]))
        export110_26.append(float(list[3]))
        import33_26.append(float(list[4]))
        export33_26.append(float(list[5]))
        import25_26.append(float(list[6]))
        export25_26.append(float(list[7]))

# %%
timeOfReading_27 = []
import110_27 = []
export110_27 = []
import33_27 = []
export33_27 = []
import25_27 = []
export25_27 = []

with open("temp/27.11.19.csv") as fileToRead:
    for line in fileToRead:
        list = line.split(',')
        timeOfReading_27.append(float(colons2dot(list[1])))
        import110_27.append(float(list[2]))
        export110_27.append(float(list[3]))
        import33_27.append(float(list[4]))
        export33_27.append(float(list[5]))
        import25_27.append(float(list[6]))
        export25_27.append(float(list[7]))

# %%
timeOfReading_28 = []
import110_28 = []
export110_28 = []
import33_28 = []
export33_28 = []
import25_28 = []
export25_28 = []

with open("temp/28.11.19.csv") as fileToRead:
    for line in fileToRead:
        list = line.split(',')
        timeOfReading_28.append(float(colons2dot(list[1])))
        import110_28.append(float(list[2]))
        export110_28.append(float(list[3]))
        import33_28.append(float(list[4]))
        export33_28.append(float(list[5]))
        import25_28.append(float(list[6]))
        export25_28.append(float(list[7]))

# %%
timeOfReading_29 = []
import110_29 = []
export110_29 = []
import33_29 = []
export33_29 = []
import25_29 = []
export25_29 = []

with open("temp/29.11.19.csv") as fileToRead:
    for line in fileToRead:
        list = line.split(',')
        timeOfReading_29.append(float(colons2dot(list[1])))
        import110_29.append(float(list[2]))
        export110_29.append(float(list[3]))
        import33_29.append(float(list[4]))
        export33_29.append(float(list[5]))
        import25_29.append(float(list[6]))
        export25_29.append(float(list[7]))

# %%
#print(timeOfReading_26)
#print(import110_26[:145])
# if length is more than 144, the csv files have not been removed
#print(len(timeOfReading_26))
#print(len(import110_26))

# Find the time location in array
i=0
startTime = 10.0
endTime = 14.0
time2locate = [0, startTime, endTime]
# Store the array position
timeLocation = []

# Iterate for start and end time
for j in range(1, len(time2locate)):
    # locate position
    for recordTime in timeOfReading_26:
        if recordTime >= time2locate[j-1] and recordTime <= time2locate[j]:
            i += 1
    # Save position
    timeLocation.append(i-j)

print('Time {} is {} and time {} is {} in array'
          .format(startTime, timeLocation[0], endTime, timeLocation[1]))

#print(timeOfReading_26[timeLocation[0]+1:timeLocation[1]+1])
print(sum(import33_26[timeLocation[0]+1:timeLocation[1]+1]))
#print(files)
# Delete the csv files. Otherwise they will append in next run
for filenames in files:
    os.remove(filenames)
# Out:
# Time 10.0 is 59 and time 14.0 is 83 in array
# 6557.79

# %%
timeLocation
# Out:
# [59, 83]

# %%
#print(timeOfReading_26)
#print(import110_26)

# %%
# debug step if the plot rolls back
#plt.plot(timeOfReading_26[:145],import110_26[:145], label = '110 KV import')

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2, figsize=(20,50))

ax1.plot(timeOfReading_26,import110_26, label = '110 KV import')
ax1.plot(timeOfReading_26,import33_26, label = '33 KV import')
ax1.plot(timeOfReading_26,import25_26, label = '25 KV import')

ax1.grid(True)
ax1.legend(loc="upper left")
ax1.set_xticks(np.arange(0,25,2))
ax1.title.set_text('Imports on 26.11.19')
bbox = ax1.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("26.import.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax2.plot(timeOfReading_26,export110_26, label = '110 KV export')
ax2.plot(timeOfReading_26,export33_26, label = '33 KV export')
ax2.plot(timeOfReading_26,export25_26, label = '25 KV export')

ax2.grid(True)
ax2.legend(loc="upper left")
ax2.set_xticks(np.arange(0,25,2))
ax2.title.set_text('Exports on 26.11.19')
bbox = ax2.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("26.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax3.plot(timeOfReading_27,import110_27, label = '110 KV import')
ax3.plot(timeOfReading_27,import33_27, label = '33 KV import')
ax3.plot(timeOfReading_27,import25_27, label = '25 KV import')

ax3.grid(True)
ax3.legend(loc="upper left")
ax3.set_xticks(np.arange(0,25,2))
ax3.title.set_text('Imports on 27.11.19')
bbox = ax3.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("27.import.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax4.plot(timeOfReading_27,export110_27, label = '110 KV export')
ax4.plot(timeOfReading_27,export33_27, label = '33 KV export')
ax4.plot(timeOfReading_27,export25_27, label = '25 KV export')

ax4.grid(True)
ax4.legend(loc="upper left")
ax4.set_xticks(np.arange(0,25,2))
ax4.title.set_text('Exports on 27.11.19')
bbox = ax4.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("27.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax5.plot(timeOfReading_28,import110_28, label = '110 KV import')
ax5.plot(timeOfReading_28,import33_28, label = '33 KV import')
ax5.plot(timeOfReading_28,import25_28, label = '25 KV import')

ax5.grid(True)
ax5.legend(loc="upper left")
ax5.set_xticks(np.arange(0,25,2))
ax5.title.set_text('Imports on 28.11.19')
bbox = ax5.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("28.import.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax6.plot(timeOfReading_28,export110_28, label = '110 KV export')
ax6.plot(timeOfReading_28,export33_28, label = '33 KV export')
ax6.plot(timeOfReading_28,export25_28, label = '25 KV export')
ax6.title.set_text('Exports on 28.11.19')

ax6.grid(True)
ax6.legend(loc="upper left")
ax6.set_xticks(np.arange(0,25,2))
bbox = ax6.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("28.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax7.plot(timeOfReading_29,import110_29, label = '110 KV import')
ax7.plot(timeOfReading_29,import33_29, label = '33 KV import')
ax7.plot(timeOfReading_29,import25_29, label = '25 KV import')

ax7.grid(True)
ax7.legend(loc="upper left")
ax7.set_xticks(np.arange(0,25,2))
ax7.title.set_text('Imports on 29.11.19')
bbox = ax7.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("29.import.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax8.plot(timeOfReading_29,export110_29, label = '110 KV export')
ax8.plot(timeOfReading_29,export33_29, label = '33 KV export')
ax8.plot(timeOfReading_29,export25_29, label = '25 KV export')

ax8.grid(True)
ax8.legend(loc="upper left")
ax8.set_xticks(np.arange(0,25,2))
ax8.title.set_text('Exports on 29.11.19')
bbox = ax8.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("29.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

plt.show()

# %%
fig, (ax1, ax3, ax5) = plt.subplots(3,1, figsize=(20,20))
fig.subplots_adjust(right=0.75)

ax2 = ax1.twinx()

ax1.plot(timeOfReading_26,import110_26, color='r', label = '110 KV import')

ax2.plot(timeOfReading_26,export110_26, label = '110 KV export')


ax1.grid(True)
ax1.legend(loc="upper center")
ax2.legend(loc="upper left")
ax1.set_xticks(np.arange(0,25,2))
ax1.title.set_text('110 KV Import/Export on 26.11.19')
bbox = ax1.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("26.110.import.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax4 = ax3.twinx()

ax3.plot(timeOfReading_26,import33_26, color='r', label = '33 KV import')

ax4.plot(timeOfReading_26,export33_26, label = '33 KV export')


ax3.grid(True)
ax3.legend(loc="upper center")
ax4.legend(loc="upper left")
ax3.set_xticks(np.arange(0,25,2))
ax3.title.set_text('33 KV Import/Export on 26.11.19')
bbox = ax3.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("26.33.import.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

ax6 = ax5.twinx()

ax5.plot(timeOfReading_26,import25_26, color='r', label = '25 KV import')

ax6.plot(timeOfReading_26,export25_26, label = '25 KV export')


ax5.grid(True)
ax5.legend(loc="upper center")
ax6.legend(loc="upper left")
ax5.set_xticks(np.arange(0,25,2))
ax5.title.set_text('25 KV Import/Export on 26.11.19')
bbox = ax5.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("26.25.import.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

# %%
print('''
Total energy received at 110 Kv is {0:8.2f}
sent out energy at 110 KV is {1:8.2f}
Total energy consumed at 33 KV is {2:8.2f}
exported energy at 33 KV is {3:8.2f}
Total energy consumed at 25 KV is {4:8.2f}
regenerated energy at 25 KV is {5:8.2f}
'''.format(sum(import110_26),sum(export110_26),sum(import33_26),sum(export33_26,),
          sum(import25_26),sum(export25_26)))

print('''
Energy consumed in the 33KV grid is:   
    from 0am to 4am:     {0:8.2f}kwh
    from 4am to 8am:     {1:8.2f}kwh
    from 8am to 12pm:    {2:8.2f}kwh
    from 12pm to 4pm:    {3:8.2f}kwh
    from 4pm to 8pm:     {4:8.2f}kwh
    from 0am to 4am:     {5:8.2f}kwh
    
    Lowest Consumption period:
    from 10am to 2pm:    {6:8.2f}kwh

'''.format(sum(import33_26[0:25]),sum(import33_26[25:49]),
           sum(import33_26[49:73]),sum(import33_26[73:97]),
           sum(import33_26[97:121]),sum(import33_26[121:144]),
           sum(import33_26[timeLocation[0]:timeLocation[1]]),
          )
     )

print('''
On 26th Nov, 2019

110 Kv Import: {0:8.2f}
Consumed
    33 KV    :  {1:8.2f}
    25 KV    :  {2:8.2f}
Regenerated for outside consumption
    25 KV    : -{3:8.2f}
    33 KV    : -{4:8.2f}
    ---------------------
    Total    : {5:8.2f}
    
Unacounted   :  {6:8.2f}
110 Kv Export:  {7:8.2f}
'''.format(sum(import110_26),sum(import33_26),sum(import25_26),
           sum(export25_26),sum(export33_26),
          (sum(import33_26)+sum(import25_26)-sum(export25_26,)-sum(export33_26)),
          (sum(import110_26)-(sum(import33_26)+sum(import25_26)-sum(export25_26,)-sum(export33_26))),
            sum(export110_26),
          )
     )

print('''
On 27th Nov, 2019

110 Kv Import: {0:8.2f}
Consumed
    33 KV    :  {1:8.2f}
    25 KV    :  {2:8.2f}
Regenerated for outside consumption
    25 KV    : -{3:8.2f}
    33 KV    : -{4:8.2f}
    ---------------------
    Total    : {5:8.2f}
    
Unacounted   :  {6:8.2f}
110 Kv Export:  {7:8.2f}
'''.format(sum(import110_27),sum(import33_27),sum(import25_27),
           sum(export25_27),sum(export33_27),
          (sum(import33_27)+sum(import25_27)-sum(export25_27,)-sum(export33_27)),
          (sum(import110_27)-(sum(import33_27)+sum(import25_27)-sum(export25_27,)-sum(export33_27))),
            sum(export110_27),
          )
     )

print('''
On 28th Nov, 2019

110 Kv Import: {0:8.2f}
Consumed
    33 KV    :  {1:8.2f}
    25 KV    :  {2:8.2f}
Regenerated for outside consumption
    25 KV    : -{3:8.2f}
    33 KV    : -{4:8.2f}
    ---------------------
    Total    : {5:8.2f}
    
Unacounted   :  {6:8.2f}
110 Kv Export:  {7:8.2f}
'''.format(sum(import110_28),sum(import33_28),sum(import25_28),
           sum(export25_28),sum(export33_28),
          (sum(import33_28)+sum(import25_28)-sum(export25_28,)-sum(export33_28)),
          (sum(import110_28)-(sum(import33_28)+sum(import25_28)-sum(export25_28,)-sum(export33_28))),
            sum(export110_28),
          )
     )
# Out:
# Total energy received at 110 Kv is 112731.03
# sent out energy at 110 KV is   118.93
# Total energy consumed at 33 KV is 59390.81
# exported energy at 33 KV is     4.29
# Total energy consumed at 25 KV is 54736.51
# regenerated energy at 25 KV is  1668.87
#
#
# Energy consumed in the 33KV grid is:
#     from 0am to 4am:      7408.83kwh
#     from 4am to 8am:     10061.09kwh
#     from 8am to 12pm:     8011.10kwh
#     from 12pm to 4pm:     9198.97kwh
#     from 4pm to 8pm:     14666.96kwh
#     from 0am to 4am:     10043.86kwh
#
#     Lowest Consumption period:
#     from 10am to 2pm:     6601.65kwh
#
#
#
# On 26th Nov, 2019
#
# 110 Kv Import: 112731.03
# Consumed
#     33 KV    :  59390.81
#     25 KV    :  54736.51
# Regenerated for outside consumption
#     25 KV    : - 1668.87
#     33 KV    : -    4.29
#     ---------------------
#     Total    : 112454.16
#
# Unacounted   :    276.87
# 110 Kv Export:    118.93
#
#
# On 27th Nov, 2019
#
# 110 Kv Import: 114998.38
# Consumed
#     33 KV    :  61129.06
#     25 KV    :  54962.62
# Regenerated for outside consumption
#     25 KV    : - 1496.99
#     33 KV    : -    0.16
#     ---------------------
#     Total    : 114594.53
#
# Unacounted   :    403.85
# 110 Kv Export:    141.52
#
#
# On 28th Nov, 2019
#
# 110 Kv Import: 115761.18
# Consumed
#     33 KV    :  62684.99
#     25 KV    :  54316.70
# Regenerated for outside consumption
#     25 KV    : - 1501.25
#     33 KV    : -    3.43
#     ---------------------
#     Total    : 115497.01
#
# Unacounted   :    264.17
# 110 Kv Export:     58.76

# %%
fig, ax1 = plt.subplots(figsize=(20,5))

objects = ('110', '33', '25')
y = np.arange(len(objects))

kwhImports = [sum(import110_26), sum(import33_26), sum(import25_26)]
kwhExports = [sum(export110_26), sum(export33_26), sum(export25_26)]

ax2 = ax1.twinx()
ax1.bar(y, kwhImports,0.2, align='edge', color='r', label = 'Import', alpha = 0.5)
ax2.bar(y, kwhExports,0.2, align='center', color='g', label = 'Export', alpha = 0.5)

ax1.legend(loc="upper center")
ax2.legend(loc="upper left")

ax1.grid(True)
#ax2.grid(True)
plt.xticks(y, objects)
plt.ylabel('Energy in KWH')
plt.title('Import and Export')

plt.show()
bbox = ax1.get_tightbbox(fig.canvas.get_renderer())
fig.savefig("26.all.import.export.png", bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
# Data for a three-dimensional line
fig = plt.figure()
ax = fig.gca(projection='3d')

zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
plt.show()

# %%
#mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()

# %%
# Data for three-dimensional scattered points
fig = plt.figure()
ax = fig.gca(projection='3d')

zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
#ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(1, 30, 30)
xline = 15 * np.random.random(30)
yline = np.floor(5 * np.random.random(30))
plt.bar(zline, xline)
plt.bar(zline, yline, bottom=xline)

#yline =  10 + np.random.randint(low = 0, high = 3, size = 30) 
#ax.scatter3D(xline, yline, zline, 'gray')
#print(zline)
#print(xline)
#print(yline)
# Out:
# <BarContainer object of 30 artists>

# %%
ax = plt.axes(projection='3d')
# Data for three-dimensional scattered points
zdata = np.linspace(1, 30, 30)
xdata = 15 * np.random.random(30)
ydata = np.floor(5 * np.random.random(30))
ax.bar(zdata, ydata, xdata,   );

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
